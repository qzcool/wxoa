# %% [markdown]
# # 步骤
# 1. 函数封装
# 2. API:打包为Pip
# 3. Django:网页服务

# %%
import pandas as pd
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import requests, time, re, math, openpyxl, datetime, os, shutil, psutil
from tqdm import *
import xlwings as xw
from selenium import webdriver
#from splinter import Browser
#from pandas.io.json import json_normalize

# Def get position function: 增加程序对数据源结构变化的稳定性
def f_p(df, feature):
    feature_list = df.iloc[:,0].get_values().tolist() # 第一列为特征名称，Index为连续自然数
    return [i for i,x in enumerate(feature_list) if x == feature][0]

# Def Check Nan Function
# https://stackoverflow.com/questions/944700/how-can-i-check-for-nan-in-python
def is_nan(x):
    return isinstance(x, float) and math.isnan(x)

# Get current file path for migration consistency
path = os.getcwd().replace('\\','/') #r'%s' % os.getcwd().replace('\\','/')

# 定义函数：从文本中根据数字类型提取Int或者Float数值
def find_number(text):
    if len(re.findall(r'\.',text)) == 0:
        return float(re.findall(r'\d+',text.replace(",", ""))[0])
    else:
        return float(re.findall(r'\d+\.\d+',text.replace(",", ""))[0])

# %%
keywords = ['个股期权','期权','场外期权','衍生品','杠杆','配资']

# %%
df = pd.DataFrame(columns=['关键字','公众号名称','公众号网址','功能介绍','微信认证','最近文章'])

# type1:公众号搜索；type2:文章搜索
try:
    for keyword in tqdm(keywords):
        url = 'http://weixin.sogou.com/weixin?type=1&query='+keyword
        headers = {'User-Agent': str(UserAgent().random)}
        r = requests.get(url,headers)
        r.encoding = 'utf-8'
        soup = BeautifulSoup(r.text,'lxml')
        page_numbers = len(soup.find('div',class_='p-fy',id='pagebar_container').find_all('a'))

        for p in range(page_numbers):
            url = 'http://weixin.sogou.com/weixin?type=1&page='+str(p)+'&query='+'个股期权'
            r = requests.get(url,headers)
            r.encoding = 'utf-8'
            soup = BeautifulSoup(r.text,'lxml')

            for i in range(len(soup.find_all('li',id=True))):
                if len(soup.find_all('li',id=True)[i].find_all('dl')) == 1:
                    df = df.append({'关键字':keyword,\
                                    '公众号名称':soup.find_all('li',id=True)[i].find_all('a',target="_blank")[1].get_text(),\
                                    '功能介绍':soup.find_all('li',id=True)[i].find_all('dl')[0].get_text().replace('\n功能介绍：\n','').replace('\n','')\
                                   },ignore_index=True)
                elif len(soup.find_all('li',id=True)[i].find_all('dl')) == 2:
                    df = df.append({'关键字':keyword,\
                                    '公众号名称':soup.find_all('li',id=True)[i].find_all('a',target="_blank")[1].get_text(),\
                                    '功能介绍':soup.find_all('li',id=True)[i].find_all('dl')[0].get_text().replace('\n功能介绍：\n','').replace('\n',''),\
                                    '最近文章':soup.find_all('li',id=True)[i].find_all('dl')[1].get_text().split('\n\n')[1].split('document')[0]\
                                   },ignore_index=True)
                else:
                    df = df.append({'关键字':keyword,\
                                    '公众号名称':soup.find_all('li',id=True)[i].find_all('a',target="_blank")[1].get_text(),\
                                    '功能介绍':soup.find_all('li',id=True)[i].find_all('dl')[0].get_text().replace('\n功能介绍：\n','').replace('\n',''),\
                                    '微信认证':soup.find_all('li',id=True)[i].find_all('dl')[1].get_text().split('：\n')[1][:-1],\
                                    '最近文章':soup.find_all('li',id=True)[i].find_all('dl')[1].get_text().split('\n\n')[1].split('document')[0]\
                                   },ignore_index=True)
            time.sleep(5)
        time.sleep(5)
except AttributeError as e:
    print ('访问过于频繁，请设置time.sleep()!')
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# 访问过于频繁，请设置time.sleep()!

# %%
df
# Out:
#       关键字       公众号名称 公众号网址  \
# 0    个股期权       个股期权盈   NaN
# 1    个股期权   个股期权咨询与询价   NaN
# 2    个股期权      股票个股期权   NaN
# 3    个股期权     个股期权操盘手   NaN
# 4    个股期权     个股期权大讲堂   NaN
# 5    个股期权       个股期权6   NaN
# 6    个股期权    个股期权交易策略   NaN
# 7    个股期权      个股期权管家   NaN
# 8    个股期权    场外个股期权解说   NaN
# 9    个股期权    个股期权交易规则   NaN
# 10   个股期权       个股期权盈   NaN
# 11   个股期权   个股期权咨询与询价   NaN
# 12   个股期权      股票个股期权   NaN
# 13   个股期权     个股期权操盘手   NaN
# 14   个股期权     个股期权大讲堂   NaN
# 15   个股期权       个股期权6   NaN
# 16   个股期权    个股期权交易策略   NaN
# 17   个股期权      个股期权管家   NaN
# 18   个股期权    场外个股期权解说   NaN
# 19   个股期权    个股期权交易规则   NaN
# 20   个股期权      米仓个股期权   NaN
# 21   个股期权    场外个股期权咨询   NaN
# 22   个股期权    股票场外个股期权   NaN
# 23   个股期权      jr个股期权   NaN
# 24   个股期权      个股期权之家   NaN
# 25   个股期权   个股期权家交易中心   NaN
# 26   个股期权    个股期权招商平台   NaN
# 27   个股期权      两市个股期权   NaN
# 28   个股期权      红牛个股期权   NaN
# 29   个股期权     大赢家个股期权   NaN
# ..    ...         ...   ...
# 320   衍生品      米仓个股期权   NaN
# 321   衍生品    场外个股期权咨询   NaN
# 322   衍生品    股票场外个股期权   NaN
# 323   衍生品      jr个股期权   NaN
# 324   衍生品      个股期权之家   NaN
# 325   衍生品   个股期权家交易中心   NaN
# 326   衍生品    个股期权招商平台   NaN
# 327   衍生品      两市个股期权   NaN
# 328   衍生品      红牛个股期权   NaN
# 329   衍生品     大赢家个股期权   NaN
# 330   衍生品    正规场外个股期权   NaN
# 331   衍生品   场外个股期权OTC   NaN
# 332   衍生品     嘉天下个股期权   NaN
# 333   衍生品    红牛场外个股期权   NaN
# 334   衍生品      赢在个股期权   NaN
# 335   衍生品  股票个股期权交易平台   NaN
# 336   衍生品     股乐通个股期权   NaN
# 337   衍生品  场外个股期权报价咨询   NaN
# 338   衍生品      个股场外期权   NaN
# 339   衍生品    丰源个股场外期权   NaN
# 340   衍生品    种子个股场外期权   NaN
# 341   衍生品      个股期权资讯   NaN
# 342   衍生品      个股期权交易   NaN
# 343   衍生品     个股期权点点通   NaN
# 344   衍生品    个股期权服务平台   NaN
# 345   衍生品       个股期权宝   NaN
# 346   衍生品    场外个股期权中心   NaN
# 347   衍生品      个股期权攻略   NaN
# 348   衍生品      鸿牛个股期权   NaN
# 349   衍生品   场外个股期权那些事   NaN
#
#                                                   功能介绍             微信认证  \
# 0                  了解个股期权、场外期权从“个股期权盈”开始,股票期权的资讯与学习平台.     深圳高登投资咨询有限公司
# 1            个股期权、原油期货配资、商品投资咨询、指导,提供最新金融咨讯,资深分析师一对一解答   杭州恒牛金融信息服务有限公司
# 2        本公众号专注于场外个股期权相关业务,为客户提供及时的场外个股期权报价,价格优惠,服务到位!              NaN
# 3    场外个股期权行情,询价,开户,软件,下载.交易,投资,一对一服务,策略定制,专业操盘手,股票...              NaN
# 4    风靡美国的场外个股期权登陆中国,由国家颁发的正规出台法律,本公众平台力做最权威的个股期权讲解...              NaN
# 5                                           个股期权的介绍和推广              NaN
# 6                  介绍交流个股期权交易规则、交易策略等,看好期权在中国市场的长远发展!!              NaN
# 7                              小金额撬动大资金,个股期权推荐,每天带你赚赚赚              NaN
# 8                                            暂时无提供任何产品              NaN
# 9    投资A股就选 吾股哈哈 官网 www.wuguhaha.com 股票日内交易 杠杠比例放大1...              NaN
# 10                 了解个股期权、场外期权从“个股期权盈”开始,股票期权的资讯与学习平台.     深圳高登投资咨询有限公司
# 11           个股期权、原油期货配资、商品投资咨询、指导,提供最新金融咨讯,资深分析师一对一解答   杭州恒牛金融信息服务有限公司
# 12       本公众号专注于场外个股期权相关业务,为客户提供及时的场外个股期权报价,价格优惠,服务到位!              NaN
# 13   场外个股期权行情,询价,开户,软件,下载.交易,投资,一对一服务,策略定制,专业操盘手,股票...              NaN
# 14   风靡美国的场外个股期权登陆中国,由国家颁发的正规出台法律,本公众平台力做最权威的个股期权讲解...              NaN
# 15                                          个股期权的介绍和推广              NaN
# 16                 介绍交流个股期权交易规则、交易策略等,看好期权在中国市场的长远发展!!              NaN
# 17                             小金额撬动大资金,个股期权推荐,每天带你赚赚赚              NaN
# 18                                           暂时无提供任何产品              NaN
# 19   投资A股就选 吾股哈哈 官网 www.wuguhaha.com 股票日内交易 杠杠比例放大1...              NaN
# 20                                   金融服务,提供优质的场外期权服务!              NaN
# 21   覆盖场外个股期权要闻,场外个股期权评论,场外个股期权数据,场外个股期权知识,场外个股期权法规...              NaN
# 22             专注股票行情分析,解套策略交流,个股期权业务咨询,认购询价.诚信为本,合作共赢              NaN
# 23   股票期货沙龙,金融培训;打造一个文化平台,营造一个快乐家园(俱乐部运作,主题:生活与投资.诚...              NaN
# 24               在私募间产品报价与服务系统,寻找交易对手方,与客户签订完全个性化的期权合约  湖南省金瑞鼎盛资产管理有限公司
# 25   我们公司专业提供以下服务: 1、期权平台搭建; 2、期权平台招运营中心、省总代理; 3、期权...    江西省银华投资管理有限公司
# 26   “期权大师”是专门从事金融类个股期权的综合性金融服务提供商.以“立足专业化商品金融市场、大力...              NaN
# 27   两市个股期权为投资者提供最丰富的期权基础知识、最及时的行业动态、最全面的策略解读,帮助您方便...    苏州恒驰顺投资股份有限公司
# 28   红牛网是专业性金融交易平台,是以场外期权业务为主,集股票、股权、债券、基金、咨询等业务于一体...              NaN
# 29                                             大赢家个股期权  大赢家金融服务(深圳)有限公司
# ..                                                 ...              ...
# 320                                  金融服务,提供优质的场外期权服务!              NaN
# 321  覆盖场外个股期权要闻,场外个股期权评论,场外个股期权数据,场外个股期权知识,场外个股期权法规...              NaN
# 322            专注股票行情分析,解套策略交流,个股期权业务咨询,认购询价.诚信为本,合作共赢              NaN
# 323  股票期货沙龙,金融培训;打造一个文化平台,营造一个快乐家园(俱乐部运作,主题:生活与投资.诚...              NaN
# 324              在私募间产品报价与服务系统,寻找交易对手方,与客户签订完全个性化的期权合约  湖南省金瑞鼎盛资产管理有限公司
# 325  我们公司专业提供以下服务: 1、期权平台搭建; 2、期权平台招运营中心、省总代理; 3、期权...    江西省银华投资管理有限公司
# 326  “期权大师”是专门从事金融类个股期权的综合性金融服务提供商.以“立足专业化商品金融市场、大力...              NaN
# 327  两市个股期权为投资者提供最丰富的期权基础知识、最及时的行业动态、最全面的策略解读,帮助您方便...    苏州恒驰顺投资股份有限公司
# 328  红牛网是专业性金融交易平台,是以场外期权业务为主,集股票、股权、债券、基金、咨询等业务于一体...              NaN
# 329                                            大赢家个股期权  大赢家金融服务(深圳)有限公司
# 330  “期权大师”是一家专门从事金融类个股期权的综合性金融服务提供商.以“立足专业化商品金融市场、...    惠州市大期信息咨询有限公司
# 331                      我们以量化投资为主,在大概率的基础上引领客户获取稳健收益.     江苏鼎智投资管理有限公司
# 332        匠心独运的方案,丰富完善的资讯.国内领先场外个股期权权威机构,给您最个性化的期权合约.     安徽伽蓝投资管理有限公司
# 333  红牛场外个股期权是专业性金融交易平台,是以场外期权业务为主,集股票、股权、债券、基金、咨询等...              NaN
# 334  个股期权以其风险有限盈利无限的投资特性,2018年发展必将如火如荼,众多投资人早已摩拳擦掌,...     北京数字掘金科技有限公司
# 335       个股期权投资交易平台,提供最权威的投资操作策略,建议分析,行情后续布局,欢迎各位大佬咨询   福建凯泰祥来投资管理有限公司
# 336  提供股票资讯:每日热点板块个股,盘中推送相关买卖点,大盘走势分析,在线诊股,财经新闻盘点,特...              NaN
# 337                   场外个股期权专业知识普及、券商通道,专业的策略服务降低权利金支出     济南拉可电子商务有限公司
# 338                          由券商充当期权卖方,与客户签订完全个性化的期权合约   厦门可牛金融技术服务有限公司
# 339                         由券商充当期权卖方,与客户签订完全个性化的期权合约.   深圳市田丰源投资管理有限公司
# 340                                  提供场外期权相关知识,资讯等信息.   福州种子金服信息技术有限公司
# 341                         场外个股期权基础知识解读;股票交易圣经;机构持仓披露              NaN
# 342                                  上海启德航空启德航空投资入股专用号              NaN
# 343  伴随着中国金融衍生品市场新成员——期权的登场,为广大投资者精心打造了行业内最权威,专业的公众...              NaN
# 344                        个股场外期权、股票资讯、荐股诊股、原油期货、恒生指数.              NaN
# 345  个股期权合约是指由证券交易所统一制定的、规定合约买方有权在将来某一段时间以约定的价格买入或者...              NaN
# 346  汇聚国内外顶尖电子商务平台优势;致力于建立国内最权威; 最专业; 最规范; 最安全资产管理平...              NaN
# 347                  个股期权专业解答,对市场衍生品的解析,针对目前市场行情的分析与指导              NaN
# 348                     原创分析、金融、投资、股票、期权、财经探索,安全边际守望者!              NaN
# 349                                没有废话,全是干货的个股期权的公众账号              NaN
#
#                             最近文章
# 0
# 1
# 2           《五月财富倍增计划,神秘大咖,黄金策略》
# 3              股票期权是什么?最标准的答案在这里
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8        强势个股分析:002359北讯集团的周线走势图
# 9                            NaN
# 10
# 11
# 12          《五月财富倍增计划,神秘大咖,黄金策略》
# 13             股票期权是什么?最标准的答案在这里
# 14                           NaN
# 15                           NaN
# 16                           NaN
# 17                           NaN
# 18       强势个股分析:002359北讯集团的周线走势图
# 19                           NaN
# 20       看大佬期权“新玩法”,发展空间巨大——个股期权
# 21         两个月狂赚30倍 大师乔治索罗斯的期权故事
# 22               期权产品:资本市场新型投资种类
# 23        【期权爱情故事】未来可“期”,“权”因有你!
# 24
# 25
# 26
# 27
# 28
# 29
# ..                           ...
# 320      看大佬期权“新玩法”,发展空间巨大——个股期权
# 321        两个月狂赚30倍 大师乔治索罗斯的期权故事
# 322              期权产品:资本市场新型投资种类
# 323       【期权爱情故事】未来可“期”,“权”因有你!
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# 342                          NaN
# 343  股权的魅力——小米IPO文件曝光A轮回报可达350倍!
# 344         重磅!四部委发布金融机构资管业务新规落地
# 345    看炒股高手是如何利用个股场外期权工具完美暴击庄家的
# 346  看了巴菲特58年的每笔投资,我明白了大多数人亏损的真相
# 347                          NaN
# 348      伊核协议事件影响持续 亚市早盘国际油价继续走高
# 349                          NaN
#
# [350 rows x 6 columns]

# %%
df.to_excel('期权公众号数据库.xlsx',encoding='gb18030')
